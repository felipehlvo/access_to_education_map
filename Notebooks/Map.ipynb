# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
from shapely import wkt

# %%
access_df = pd.read_csv(
        f'gs://capstone_access_data/access_df.csv', index_col=0)
access_df.head()
# Out:
#                 state  n_households  n_people  avg_monthly_earnings  \
# sector_id
# 170025105000002    TO         115.0     300.0                648.06
# 170030105000001    TO         286.0    1123.0                927.45
# 170030105000002    TO         294.0    1101.0                478.33
# 170030105000003    TO         102.0     385.0                453.32
# 170030105000004    TO          56.0     245.0                368.55
#
#                  n_people_15to17_white  n_people_15to17_black  \
# sector_id
# 170025105000002                    1.0                    0.0
# 170030105000001                   10.0                    2.0
# 170030105000002                   11.0                    0.0
# 170030105000003                    3.0                    1.0
# 170030105000004                    3.0                    0.0
#
#                  n_people_15to17_asian  n_people_15to17_parda  \
# sector_id
# 170025105000002                    0.0                   10.0
# ...

# %%
access_df = pd.read_csv("/Users/feliphlvo/Documents/Minerva/Capstone/data/local/access_df.csv",index_col=0)
access_df = gpd.GeoDataFrame(access_df, geometry = access_df["geometry"].apply(wkt.loads), crs = "EPSG:5641")
# Out:
# /Users/feliphlvo/opt/anaconda3/envs/cap_env/lib/python3.10/site-packages/geopandas/array.py:93: ShapelyDeprecationWarning:
#
# __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.

# %%
access_df = access_df.to_crs(epsg=4326)
# Out:
# /Users/feliphlvo/opt/anaconda3/envs/cap_env/lib/python3.10/site-packages/geopandas/array.py:93: ShapelyDeprecationWarning:
#
# __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.

# %%
access_df.head()
# Out:
#                 state  n_households  n_people  avg_monthly_earnings  \
# sector_id
# 170025105000002    TO         115.0     300.0                648.06
# 170030105000001    TO         286.0    1123.0                927.45
# 170030105000002    TO         294.0    1101.0                478.33
# 170030105000003    TO         102.0     385.0                453.32
# 170030105000004    TO          56.0     245.0                368.55
#
#                  n_people_15to17_white  n_people_15to17_black  \
# sector_id
# 170025105000002                    1.0                    0.0
# 170030105000001                   10.0                    2.0
# 170030105000002                   11.0                    0.0
# 170030105000003                    3.0                    1.0
# 170030105000004                    3.0                    0.0
#
#                  n_people_15to17_asian  n_people_15to17_parda  \
# sector_id
# 170025105000002                    0.0                   10.0
# ...

# %%
subset_df = access_df[access_df["city_name"] == "São Paulo"]
str_json = subset_df[["geometry", "city_name"]].to_json()

# %%
subset_df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 subset_df.columns
#
# NameError: name 'subset_df' is not defined

# %%
fig = px.choropleth_mapbox(access_df, geojson=access_df, locations=access_df.index, color="3sfca_n_classes",
                           mapbox_style="open-street-map", opacity=0.5, center={"lat": -23.5558, "lon":-46.6396}, zoom=9.5,
                           hover_data=["city_name"])
fig.show()
